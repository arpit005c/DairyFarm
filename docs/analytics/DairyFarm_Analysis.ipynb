# %% [markdown]
# # Phase 13: DairyFarm Analytical Exploration
#
# This notebook demonstrates the exploratory data analysis for the DairyFarm project using **NumPy** and PostgreSQL.
# It connects to the database utilizing existing configurations and performs numerical aggregation.

# %%
import os
import sys
import numpy as np

# Ensure the project root is in the path to import backend modules
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

from backend.app.analytics.analytics_service import AnalyticsOrchestrator

print("Environment initialized.")

# %% [markdown]
# ## 1. Analytics Orchestrator Execution
# Retrieve the summary which processes data from the repositories via NumPy arrays.

# %%
orchestrator = AnalyticsOrchestrator()
summary = orchestrator.get_summary()

import json
print(json.dumps(summary, indent=2))

# %% [markdown]
# ## 2. Validation & Findings
# The data above confirms that we can successfully:
# 1. Pull real data from PostgreSQL
# 2. Prepare it dynamically via Repository logic
# 3. Perform calculations (`sum`, `mean`, `max`, `min`, `std`) via NumPy.
#
# **Note:** Streamlit and Data Visualizations are reserved for Phase 14.
